# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import keyword
print("The list of keywords are : ")
print(keyword.kwlist)
# Out:
# The list of keywords are :
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # functions

# %% [markdown]
# # =========================================
# # 1. BUILT-IN FUNCTIONS
# # =========================================
#
# print("Hello")
# # Use: Display output on screen
#
# type(10)
# # Use: Check data type
#
# len([1,2,3])
# # Use: Get number of items
#
# input("Enter: ")
# # Use: Take user input
#
# int("10")
# # Use: Convert to integer
#
# float("3.5")
# # Use: Convert to float
#
# str(100)
# # Use: Convert to string
#
# sum([1,2,3])
# # Use: Add all elements
#
# max([1,5,2])
# # Use: Get largest value
#
# min([1,5,2])
# # Use: Get smallest value
#
# sorted([3,1,2])
# # Use: Return sorted list (new list)
#
# range(5)
# # Use: Generate sequence of numbers
#
# abs(-5)
# # Use: Absolute value
#
# round(3.456, 2)
# # Use: Round number
#
# pow(2,3)
# # Use: Power (2^3)
#
# divmod(10,3)
# # Use: Returns quotient & remainder
#
# enumerate(['a','b'])
# # Use: Get index + value pairs
#
# zip([1,2], ['a','b'])
# # Use: Combine multiple lists
#
# map(int, ["1","2"])
# # Use: Apply function to all items
#
# filter(lambda x:x>2, [1,2,3])
# # Use: Filter elements based on condition
#
#
# # =========================================
# # 2. LIST FUNCTIONS
# # =========================================
#
# l = [10,20,30]
#
# l.append(40)
# # Use: Add element at end
#
# l.insert(1,15)
# # Use: Insert at specific position
#
# l.remove(20)
# # Use: Remove element by value
#
# l.pop(1)
# # Use: Remove element by index
#
# l.index(30)
# # Use: Get index of element
#
# l.count(10)
# # Use: Count occurrences
#
# l.sort()
# # Use: Sort list permanently
#
# l.reverse()
# # Use: Reverse list
#
# l.copy()
# # Use: Copy list
#
# l.clear()
# # Use: Remove all elements
#
# l.extend([50,60])
# # Use: Add multiple elements
#
#
# # =========================================
# # 3. STRING FUNCTIONS
# # =========================================
#
# s = " Hello World "
#
# s.lower()
# # Use: Convert to lowercase
#
# s.upper()
# # Use: Convert to uppercase
#
# s.strip()
# # Use: Remove spaces from ends
#
# s.replace("Hello","Hi")
# # Use: Replace text
#
# s.split()
# # Use: Convert string → list
#
# " ".join(['a','b'])
# # Use: Convert list → string
#
# s.find("World")
# # Use: Find index (-1 if not found)
#
# s.index("World")
# # Use: Find index (error if not found)
#
# s.startswith("Hello")
# # Use: Check starting text
#
# s.endswith("World ")
# # Use: Check ending text
#
# s.count("l")
# # Use: Count occurrences
#
# s.capitalize()
# # Use: First letter uppercase
#
# s.title()
# # Use: Capitalize each word
#
# s.isdigit()
# # Use: Check if numeric
#
# s.isalpha()
# # Use: Check if alphabets only
#
# s.isalnum()
# # Use: Check alphanumeric
#
#
# # =========================================
# # 4. DICTIONARY FUNCTIONS
# # =========================================
#
# d = {"a":1, "b":2}
#
# d.get("a")
# # Use: Get value safely (no error)
#
# d.keys()
# # Use: Get all keys
#
# d.values()
# # Use: Get all values
#
# d.items()
# # Use: Get key-value pairs
#
# d.update({"c":3})
# # Use: Add/update values
#
# d.pop("a")
# # Use: Remove key
#
# d.popitem()
# # Use: Remove last inserted item
#
# d.clear()
# # Use: Empty dictionary
#
# d.copy()
# # Use: Copy dictionary
#
#
# # =========================================
# # 5. SET FUNCTIONS
# # =========================================
#
# s = {1,2,3}
#
# s.add(4)
# # Use: Add element
#
# s.remove(2)
# # Use: Remove element (error if not found)
#
# s.discard(5)
# # Use: Remove safely (no error)
#
# s.pop()
# # Use: Remove random element
#
# s.clear()
# # Use: Empty set
#
# a = {1,2}
# b = {2,3}
#
# a.union(b)
# # Use: Combine sets
#
# a.intersection(b)
# # Use: Common elements
#
# a.difference(b)
# # Use: Elements in a not in b
#
# a.symmetric_difference(b)
# # Use: Non-common elements
#
#
# # =========================================
# # 6. FILE FUNCTIONS
# # =========================================
#
# f = open("file.txt","r")
# # Use: Open file
#
# f.read()
# # Use: Read full file
#
# f.readline()
# # Use: Read one line
#
# f.readlines()
# # Use: Read all lines as list
#
# f.write("Hello")
# # Use: Write to file
#
# f.close()
# # Use: Close file
#
#
# # =========================================
# # 7. OTHER IMPORTANT
# # =========================================
#
# help(print)
# # Use: Get documentation
#
# dir(list)
# # Use: Show all functions of object
#
# id(10)
# # Use: Memory address
#
# isinstance(5,int)
# # Use: Check type
#
# all([True,True])
# # Use: True if all true
#
# any([False,True])
# # Use: True if any true
