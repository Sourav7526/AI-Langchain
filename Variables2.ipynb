# %%
a=100
print(a)
a

# %%
x, y, z = 1, 2.5, "Python"
print(x, z, y)

# %%
name=22
my_name=float(name)
my_name
# age=22
# height=172.0
# is_student=True

# print("my name is ",name)
# print("my age is ",age)

# %%
#Naming conventions
#variables name should be desciptive
#they must start with letter or an '_' and can contains letters numbwers or underscpores
#variables names are case sensitive

# %%
#errors
# name="sourav"
# firstname="sourav"
# last name="sourav"
# n2ame="newn"

# %%
# understanding variable types

# a=10
# print(a)
# print("type of a is",type(a))
# b=2.34
# print("type of b is",type(b))
# c=True  # True or False 
# print("type of c is",type(c))
# d='hello'
# print("type of d is",type(d))

# %%
# type conversion 

# age=25
# print(age)
# print(type(age))
# age_str=str(age)
# print(age_str)
# print(type(age_str))

# %%
# # error
# name="sourav"
# print(int(name))

# %%
# height=5.11
# print(int(height))

# age=22
# print(float(age))

# %%
# input output

# age=input("enter your age ily babyyy")
# print(age)
# print(type(age))

# name = input("Enter your name: ")
# print("Hello,", name, "! Welcome!")


# i = int(input("How old are you?: "))
# f = float(input("Evaluate 7/2: "))

# print(i, f)

# %%
# Dyanmic typing
# python allows to change type of variables as the program exexutes

# var=10
# print(var,type(var))


# var="hello"
# print(var,type(var))


# var=3.14
# print(var,type(var))

# %%
#simple calcualtor

num1= float(input("enter first number: "))
num2= float(input("enter second number: "))


sum=num1+num2

difference=num1-num2

product=num1*num2

quotient=num1/num2

print("sum is ",sum)
print("difference is ",difference)
print("product is ",product)
print("quotient is ",quotient)
